# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*3.141593, 100)
y = np.sin(x)
fig = plt.figure()
plt.plot(x, y)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure
